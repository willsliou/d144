# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import warnings
from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings('ignore', category=UserWarning, module='sklearn.cluster') # remove annoying warnings

# %% [markdown]
# ## Stakeholders: This analysis helps Spotify curate mood-based playlists, enables marketers to target specific audiences, and gives artists insights into song trends.
# ## Real-World Context: Playlist curation (mood playlists), marketing strategies for Spotify or advertisers, tracks with low streams but solid characteristics
#
# ## Limitations and Future Work
# ### Limitations:
# - The dataset focuses on specific audio features but lacks listener demographics (e.g., age, region).
# - Clustering results may vary with different algorithms or parameters.
# - Some features (e.g., `streams`) may dominate clustering despite standardization.
#
# ### Future Work:
# - Incorporate temporal trends to analyze how clusters change over time.
# - Add user behavior data (e.g., skips, saves) for listener-specific clusters.
# - Explore hierarchical clustering to better understand relationships between clusters.

# %% [markdown]
# # Steps

# %% [markdown]
# 1. Load in Data
# 2. Select relevant song characteristic columns like bpm, energy % for clustering
# 3. Clean data
# 4. Standardize features (mean 0, std 1) for wider streams data
# 5. Group songs by feature similarity
#     1. Optimal clusters with Elbow + Silhouette
#     2. Apply KMeans with Optimal Cluster
# 6. Understand characteristics of clutsering finding mean() of every cluster
# 7. Plot scatter and bar chart

# %% [markdown]
# ## Load in Data

# %%
# Load data
file_path = 'C:/Users/hello/OneDrive/Documents/GitHub/d144/spotify-2023.csv'
df = pd.read_csv(file_path, encoding='latin1')
print(df.shape)
df.head(5)
# Out:
# (953, 24)
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %% [markdown]
# ## Select relevant song characteristic columns like bpm, energy % for clustering

# %%
#####################################
########### Preprocessing ###########
#####################################

relevant_columns = [
    'bpm', 'danceability_%', 'valence_%', 'energy_%', 'acousticness_%',
    'instrumentalness_%', 'liveness_%', 'speechiness_%', 'streams', 
    'in_spotify_playlists'
]

# %% [markdown]
# ## Clean data by converting streams col to numeric and drop missing values rows

# %%
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')
df_cleaned = df.dropna(subset=relevant_columns)

# %% [markdown]
# ## Standardize Features

# %%
# Standardize numerical features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df_cleaned[relevant_columns])

# %% [markdown]
# ## Group Songs by Feature Similarity

# %%
# Find optimal num of clusters w Elbow Method
inertia = []
range_clusters = range(1, 11)
for k in range_clusters:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(scaled_features)
    inertia.append(kmeans.inertia_)

# %%
# Elbow Method from class (emphasize we appled elbow + silhoette during slides)
plt.figure(figsize=(8, 6))
plt.plot(range_clusters, inertia, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method: Optimal Number of Clusters')
plt.grid(True)
plt.show()

"""
Elbow Method
Why we did it: To identify the "elbow point" where adding more clusters no longer significantly improves within-cluster compactness (inertia).
What we learned: The optimal number of clusters appears to be around k=4, providing a balance between compactness and granularity.
"""

# %%
# Set kmeans with optimal number of clusters
kmeans = KMeans(n_clusters=4, random_state=42)
df_cleaned['cluster'] = kmeans.fit_predict(scaled_features)

# Cluster Analysis
# Mean feature values for each cluster
cluster_characteristics = df_cleaned.groupby('cluster')[relevant_columns].mean()
print("Cluster Characteristics:")
print(cluster_characteristics)
# Out:
# Cluster Characteristics:
#                 bpm  danceability_%  valence_%   energy_%  acousticness_%  \
# cluster
# 0        119.804071       77.412214  67.486005  69.798982       21.748092
# 1        128.505226       60.470383  36.658537  68.411150       13.222997
# 2        118.887850       64.654206  53.242991  67.196262       19.794393
# 3        121.127273       54.987879  37.569697  42.024242       68.600000
#
#          instrumentalness_%  liveness_%  speechiness_%       streams  \
# cluster
# 0                  0.374046   16.155216      13.152672  3.257577e+08
# 1                  3.034843   23.101045       8.066202  3.554735e+08
# 2                  0.289720   16.149533       8.457944  1.728902e+09
# 3                  2.775758   15.957576       7.654545  4.510466e+08
#
#          in_spotify_playlists
# cluster
# 0                 2533.155216
# 1                 2942.797909
# 2                23306.514019
# 3                 3751.103030
# ...

# %%
# Cluster visualization
pca = PCA(n_components=2) # PCA basic 2 dimensions
pca_features = pca.fit_transform(scaled_features)

# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(pca_features[:, 0], pca_features[:, 1], c=df_cleaned['cluster'], cmap='viridis', alpha=0.6)
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('Clusters Visualized in PCA-Reduced Feature Space')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

# Bar chart: feature averages per cluster
cluster_characteristics.T.plot(kind='bar', figsize=(10, 8))
plt.title('Average Feature Values by Cluster')
plt.xlabel('Features')
plt.ylabel('Average Value')
plt.legend(title='Cluster', loc='upper right')
plt.grid(axis='y')
plt.tight_layout()
plt.show()


"""
PCA Visualization of Clusters
Why we did it: To reduce high-dimensional data into two dimensions for visualization while preserving the variance in the data. This helps us observe how well-defined the clusters are.
What we learned: The clusters are fairly distinct in the PCA-reduced space, supporting the K-Means model's ability to segment tracks based on their features.
"""

# %%
# silhouette scores for different cluster numbers
silhouette_scores = []
range_clusters = range(2, 11)  # 2 clusters min
for k in range_clusters:
    kmeans = KMeans(n_clusters=k, random_state=42)
    cluster_labels = kmeans.fit_predict(scaled_features)
    score = silhouette_score(scaled_features, cluster_labels)
    silhouette_scores.append(score)


plt.figure(figsize=(8, 6))
plt.plot(range_clusters, silhouette_scores, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores for Different Numbers of Clusters')
plt.grid(True)
plt.show()

# select highest silhouette score
optimal_k = range_clusters[silhouette_scores.index(max(silhouette_scores))]
print(f"The optimal number of clusters based on the Silhouette Score is {optimal_k}.")


"""
Silhouette Scores
Why we did it: To evaluate the quality of clustering by measuring how similar a point is to its own cluster compared to other clusters. This helps determine the optimal number of clusters.
What we learned: The silhouette score is highest at k=2, indicating better separation at this value, though we opted for a higher k for more nuanced insights.
"""
# Out:
# The optimal number of clusters based on the Silhouette Score is 2.

# %%
cluster_sizes = df_cleaned['cluster'].value_counts()

# Bar plot of cluster sizes
plt.figure(figsize=(8, 6))
cluster_sizes.plot(kind='bar', color='skyblue')
plt.title('Number of Songs in Each Cluster')
plt.xlabel('Cluster')
plt.ylabel('Number of Songs')
plt.xticks(rotation=0)
plt.grid(axis='y')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.heatmap(df_cleaned[relevant_columns].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Matrix')
plt.show()

"""
Why we did it: To understand relationships between key features (e.g., energy, danceability, streams) and identify highly correlated attributes that may influence clustering.
What we learned: High correlations between features like streams and Spotify playlist presence suggest these drive cluster separations.

"""

# %%
from sklearn.metrics import pairwise_distances
intra_distances = []
for i in range(optimal_k):
    cluster_points = scaled_features[df_cleaned['cluster'] == i]
    intra_distances.append(pairwise_distances(cluster_points).mean())
print("Average intra-cluster distances:", intra_distances)
# Out:
# Average intra-cluster distances: [3.0811976407827255, 3.624183361616838]

# %% [markdown]
# ## Cluster Characteristics Summary
# | Cluster | Description                  | Features |
# |---------|------------------------------|-------------------|
# | 0       | High-energy dance tracks     | High energy, high danceability, high streams |
# | 1       | Mellow mainstream tracks     | Moderate energy, high playlist presence      |
# | 2       | Acoustic and instrumental    | High acousticness, low speechiness           |
# | 3       | Low-energy ambient tracks    | Low valence, moderate streams
